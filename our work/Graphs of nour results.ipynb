# %%
from numpy import loadtxt

# %%
# Facenet
# Bad
fb1 = loadtxt("results/results_Imposter_NourN_Bad_Facenet.txt")
fb2 = loadtxt("results/Facenet/results_Genuine_BadFacenet.txt")

# %%
import numpy as np

# %%
import seaborn as sns
sns.set_style('whitegrid')
#sns.kdeplot(dif, bw=0.5)
sns.kdeplot(fb1)
sns.kdeplot(fb2, color="red")

# %%
# Good
fg1 = loadtxt("results/results_Imposter_NourN_Good_Facenet.txt")
fg2 = loadtxt("results/Facenet/results_Genuine_GoodFacenet.txt")

# %%
import seaborn as sns
sns.set_style('whitegrid')
#sns.kdeplot(dif, bw=0.5)
sns.kdeplot(fg1)
sns.kdeplot(fg2, color="red")

# %%
# Ugly
fu1 = loadtxt("results/results_Imposter_NourN_Ugly_Facenet.txt")
fu2 = loadtxt("results/Facenet/results_Genuine_UglyFacenet.txt")

# %%
import seaborn as sns
sns.set_style('whitegrid')
#sns.kdeplot(dif, bw=0.5)
sns.kdeplot(fu1)
sns.kdeplot(fu2, color="red")

# %%
# the three lines graph
th = np.arange(0.000,1,0.001)
def cnt(ar,th):
    cnt = 0
    for i in ar:
        if i <= th:
            cnt+=1
    return cnt/len(ar)
fe_bad = np.empty(1000)
fe_good = np.empty(1000)
fe_ugly = np.empty(1000)


for i in range(1000):
    fe_bad[i] = cnt(fb1,th[i])
    fe_good[i] = cnt(fg1,th[i])
    fe_ugly[i] = cnt(fu1,th[i])
    
te_bad = np.empty(1000)
te_good = np.empty(1000)
te_ugly = np.empty(1000)


for i in range(1000):
    te_bad[i] = cnt(fb2,th[i])
    te_good[i] = cnt(fg2,th[i])
    te_ugly[i] = cnt(fu2,th[i])
    

import matplotlib.pyplot as plt

plt.plot(te_bad,fe_bad)
plt.plot(te_ugly,fe_ugly,color="red")
plt.plot(te_good,fe_good,color="green")

# %%
# the three lines graph
th = np.arange(0.000,1,0.001)

# %%
print(len(th))
# Out:
# 1000

# %%
def cnt(ar,th):
    cnt = 0
    for i in ar:
        if i <= th:
            cnt+=1
    return cnt/len(ar)
    
# print(cnt([2,5,8,1,4],2))
# Out:
# 0.4

# %%
fe_bad = np.empty(1000)
fe_good = np.empty(1000)
fe_ugly = np.empty(1000)

# %%
indx = 0
for i in range(1000):
    fe_bad[i] = cnt(fb1,th[i])
    fe_good[i] = cnt(fg1,th[i])
    fe_ugly[i] = cnt(fu1,th[i])

# %%
te_bad = np.empty(1000)
te_good = np.empty(1000)
te_ugly = np.empty(1000)

# %%
indx = 0
for i in range(1000):
    te_bad[i] = cnt(fb2,th[i])
    te_good[i] = cnt(fg2,th[i])
    te_ugly[i] = cnt(fu2,th[i])

# %%
import matplotlib.pyplot as plt

plt.plot(te_bad,fe_bad)
plt.plot(te_ugly,fe_ugly,color="red")
plt.plot(te_good,fe_good,color="green")

# %%
# DeepFace
# Bad
fb1 = loadtxt("results/results_Imposter_NourN_Bad_DeepFace.txt")
fb2 = loadtxt("results/Deepface/results_Genuine_BadDeepFace.txt")

# %%
import seaborn as sns
sns.set_style('whitegrid')
#sns.kdeplot(dif, bw=0.5)
sns.kdeplot(fb1)
sns.kdeplot(fb2, color="red")

# %%
# Good
fg1 = loadtxt("results/results_Imposter_NourN_Good_DeepFace.txt")
fg2 = loadtxt("results/Deepface/results_Genuine_GoodDeepFace.txt")

# %%
import seaborn as sns
sns.set_style('whitegrid')
#sns.kdeplot(dif, bw=0.5)
sns.kdeplot(fg1)
sns.kdeplot(fg2, color="red")

# %%
# Ugly
fu1 = loadtxt("results/results_Imposter_NourN_Ugly_DeepFace.txt")
fu2 = loadtxt("results/DeepFace/results_Genuine_UglyDeepFace.txt")

# %%
import seaborn as sns
sns.set_style('whitegrid')
#sns.kdeplot(dif, bw=0.5)
sns.kdeplot(fu1)
sns.kdeplot(fu2, color="red")

# %%
# the three lines graph
th = np.arange(0.000,1,0.001)
def cnt(ar,th):
    cnt = 0
    for i in ar:
        if i <= th:
            cnt+=1
    return cnt/len(ar)
fe_bad = np.empty(1000)
fe_good = np.empty(1000)
fe_ugly = np.empty(1000)


for i in range(1000):
    fe_bad[i] = cnt(fb1,th[i])
    fe_good[i] = cnt(fg1,th[i])
    fe_ugly[i] = cnt(fu1,th[i])
    
te_bad = np.empty(1000)
te_good = np.empty(1000)
te_ugly = np.empty(1000)


for i in range(1000):
    te_bad[i] = cnt(fb2,th[i])
    te_good[i] = cnt(fg2,th[i])
    te_ugly[i] = cnt(fu2,th[i])
    

import matplotlib.pyplot as plt

plt.plot(te_bad,fe_bad)
plt.plot(te_ugly,fe_ugly,color="red")
plt.plot(te_good,fe_good,color="green")

# %%
# VGG
# Bad
fb1 = loadtxt("results/results_Imposter_Nour_Bad_VGG-Face.txt")
fb2 = loadtxt("results/VGG/results_Genuine_bad_VGG-Face.txt")

# %%
import seaborn as sns
sns.set_style('whitegrid')
#sns.kdeplot(dif, bw=0.5)
sns.kdeplot(fb1)
sns.kdeplot(fb2, color="red")

# %%
# Good
fg1 = loadtxt("results/results_Imposter_Nour_Good_VGG-Face.txt")
fg2 = loadtxt("results/VGG/results_Genuine_GoodVGG-Face.txt")

# %%
import seaborn as sns
sns.set_style('whitegrid')
#sns.kdeplot(dif, bw=0.5)
sns.kdeplot(fg1)
sns.kdeplot(fg2, color="red")

# %%
# Ugly
fu1 = loadtxt("results/results_Imposter_Nour_Ugly_VGG-Face.txt")
fu2 = loadtxt("results/VGG/results_Genuine_UglyVGG-Face.txt")

# %%
import seaborn as sns
sns.set_style('whitegrid')
#sns.kdeplot(dif, bw=0.5)
sns.kdeplot(fu1)
sns.kdeplot(fu2, color="red")

# %%
# the three lines graph
th = np.arange(0.000,1,0.001)
def cnt(ar,th):
    cnt = 0
    for i in ar:
        if i <= th:
            cnt+=1
    return cnt/len(ar)
fe_bad = np.empty(1000)
fe_good = np.empty(1000)
fe_ugly = np.empty(1000)


for i in range(1000):
    fe_bad[i] = cnt(fb1,th[i])
    fe_good[i] = cnt(fg1,th[i])
    fe_ugly[i] = cnt(fu1,th[i])
    
te_bad = np.empty(1000)
te_good = np.empty(1000)
te_ugly = np.empty(1000)


for i in range(1000):
    te_bad[i] = cnt(fb2,th[i])
    te_good[i] = cnt(fg2,th[i])
    te_ugly[i] = cnt(fu2,th[i])
    

import matplotlib.pyplot as plt

plt.plot(te_bad,fe_bad)
plt.plot(te_ugly,fe_ugly,color="red")
plt.plot(te_good,fe_good,color="green")
